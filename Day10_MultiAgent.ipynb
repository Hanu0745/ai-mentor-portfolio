# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanu0745/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:31:05 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:31:05 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: eeaaff1b-bad0-4743-9f64-cee1f3e7bf33                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: e5bf5dcb-2d93-4195-93de-e7fbc13b9c69                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here is a placement preparation brief for TCS Digital for B.Tech students:                                     │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment (NQT variant):** Typically includes advanced aptitude, verbal ability, and 2-3         │
# │  complex coding questions (e.g., LeetCode medium-hard level).                                                   │
# │  *   **Technical Interview:** Focuses heavily on Data Structures & Algorithms (DSA), core computer science      │
# │  fundamentals (OS, DBMS, CN), projects, and sometimes specific technologies mentioned in the resume.            │
# │  *   **Managerial/HR Interview:** Assesses communication skills, career aspirations, project discussions,       │
# │  cultural fit, and behavioral aspects.                                                                          │
# │                                                                                                                 │
# │  ### Technical Stack (Key areas of knowledge)                                                                   │
# │  *   **Data Structures & Algorithms (DSA):** Fundamental requirement; strong problem-solving skills are tested  │
# │  extensively.                                                                                                   │
# │  *   **Core Programming Languages:** Proficiency in at least one language like Java, Python, C++, or C# is      │
# │  essential, including OOPs concepts.                                                                            │
# │  *   **Core Computer Science Concepts:** Solid understanding of Operating Systems, Database Management Systems  │
# │  (DBMS), and Computer Networks.                                                                                 │
# │  *   **Emerging Technologies (Conceptual/Basic):** Awareness of Cloud Computing (AWS, Azure, GCP), AI/ML, Big   │
# │  Data, or IoT concepts is beneficial for advanced roles.                                                        │
# │  *   **Web Technologies/Frameworks:** Knowledge of front-end (Angular, React) or back-end (Spring Boot,         │
# │  Node.js) frameworks can be an advantage for specific roles.                                                    │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Academic Percentage:** Generally 70% or 7 CGPA throughout 10th, 12th, and B.Tech/B.E. (aggregate of all  │
# │  semesters).                                                                                                    │
# │  *   **Educational Gaps:** A maximum of 1-2 years of academic gap is usually permissible, but often requires    │
# │  justification.                                                                                                 │
# │  *   **Backlogs:** No active backlogs at the time of application and joining are strictly enforced.             │
# │  *   **Degree:** B.E./B.Tech in Computer Science, IT, Electronics, Electrical, Mechanical, Civil, etc.,         │
# │  depending on the specific year's requirements.                                                                 │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Focus on Problem-Solving:** Increased emphasis on competitive programming skills and a strong grasp of   │
# │  DSA for complex problem-solving.                                                                               │
# │  *   **Specialized Skillsets:** Preference for candidates demonstrating knowledge or projects in AI/ML, Cloud,  │
# │  IoT, or Cybersecurity.                                                                                         │
# │  *   **Premium Talent Pool:** TCS Digital often targets students from top-tier colleges or those with           │
# │  exceptional academic and extra-curricular achievements.                                                        │
# │  *   **NQT as a Gateway:** The TCS National Qualifier Test (NQT) often serves as the primary gateway, with      │
# │  Digital-specific tests having higher difficulty levels.                                                        │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA & Coding:** Dedicate significant time to practicing Data Structures and Algorithms on         │
# │  platforms like LeetCode, HackerRank, CodeChef. Aim for medium-hard problems.                                   │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS (SQL queries, ACID          │
# │  properties), and Computer Networks.                                                                            │
# │  *   **Develop & Articulate Projects:** Work on 2-3 impactful projects, preferably using modern technologies,   │
# │  and be ready to explain your role, challenges faced, and solutions in detail.                                  │
# │  *   **Mock Interviews & Communication:** Practice mock technical and HR interviews to improve articulation,    │
# │  confidence, and ability to think on your feet.                                                                 │
# │  *   **Stay Updated:** Keep abreast of the latest technologies and industry trends relevant to TCS's digital    │
# │  transformation initiatives.                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 4ee22c12-c75c-4907-93f1-82d46cc43001                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a career at the forefront of digital innovation? TCS Digital offers premium opportunities for      │
# │  B.Tech graduates to shape the future of technology. Prepare to tackle complex challenges and join an elite     │
# │  league of tech professionals.                                                                                  │
# │                                                                                                                 │
# │  ### 1. The TCS Digital Hiring Process                                                                          │
# │                                                                                                                 │
# │  The selection journey for TCS Digital is rigorous, designed to identify top-tier talent:                       │
# │                                                                                                                 │
# │  *   **Online Assessment (NQT Variant):** This initial hurdle is an NQT variant, featuring advanced aptitude,   │
# │  verbal ability, and **2-3 complex coding challenges** (often LeetCode medium-hard level). Strong               │
# │  problem-solving skills are key.                                                                                │
# │  *   **Technical Interview:** Expect a deep dive into **Data Structures & Algorithms (DSA)**, core Computer     │
# │  Science fundamentals (Operating Systems, DBMS, Computer Networks), your academic projects, and technologies    │
# │  listed on your resume.                                                                                         │
# │  *   **Managerial/HR Interview:** This round assesses your communication skills, career aspirations, cultural   │
# │  fit, and behavioral traits. Be ready to discuss your projects, strengths, and how you handle challenges.       │
# │                                                                                                                 │
# │  ### 2. Key Technical Stack & Knowledge Areas                                                                   │
# │                                                                                                                 │
# │  To excel in TCS Digital, focus on these critical areas:                                                        │
# │                                                                                                                 │
# │  *   **Data Structures & Algorithms (DSA):** This is non-negotiable. Develop robust problem-solving abilities.  │
# │  *   **Core Programming Languages:** Proficiency in at least one — **Java, Python, C++, or C#** — including     │
# │  strong Object-Oriented Programming (OOPs) concepts.                                                            │
# │  *   **Core Computer Science Concepts:** A solid grasp of **Operating Systems, Database Management Systems      │
# │  (DBMS)**, and **Computer Networks** is essential.                                                              │
# │  *   **Emerging Technologies (Conceptual):** Basic awareness of **Cloud Computing (AWS, Azure, GCP), AI/ML,     │
# │  Big Data, or IoT** concepts is a significant advantage.                                                        │
# │  *   **Web Technologies/Frameworks:** Knowledge of front-end (Angular, React) or back-end (Spring Boot,         │
# │  Node.js) frameworks can be beneficial for specific roles.                                                      │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  Ensure you meet the fundamental requirements:                                                                  │
# │                                                                                                                 │
# │  *   **Academic Percentage:** Generally **70% or 7 CGPA** throughout 10th, 12th, and B.Tech/B.E. (aggregate     │
# │  across all semesters).                                                                                         │
# │  *   **Educational Gaps:** A maximum of **1-2 years** of academic gap is usually permissible, often requiring   │
# │  justification.                                                                                                 │
# │  *   **Backlogs:** **No active backlogs** are permitted at the time of application and joining.                 │
# │  *   **Degree:** B.E./B.Tech in Computer Science, IT, Electronics, Electrical, Mechanical, Civil, etc.,         │
# │  depending on the specific year's requirements.                                                                 │
# │                                                                                                                 │
# │  ### 4. Recent Hiring Trends                                                                                    │
# │                                                                                                                 │
# │  Stay informed about what TCS Digital is looking for:                                                           │
# │                                                                                                                 │
# │  *   **Heightened Focus on Problem-Solving:** Increased emphasis on competitive programming skills and a deep   │
# │  understanding of DSA.                                                                                          │
# │  *   **Demand for Specialized Skillsets:** Preference for candidates with demonstrable knowledge or projects    │
# │  in **AI/ML, Cloud, IoT, or Cybersecurity**.                                                                    │
# │  *   **Targeting Premium Talent:** TCS Digital often seeks students from top-tier colleges or those with        │
# │  exceptional academic and extra-curricular achievements.                                                        │
# │  *   **NQT as a Gateway:** The TCS National Qualifier Test (NQT) remains the primary entry point, with          │
# │  Digital-specific tests featuring higher difficulty levels.                                                     │
# │                                                                                                                 │
# │  ### 5. Essential Preparation Tips                                                                              │
# │                                                                                                                 │
# │  Your roadmap to success:                                                                                       │
# │                                                                                                                 │
# │  *   **Master DSA & Coding:** Dedicate substantial time to practicing Data Structures and Algorithms on         │
# │  platforms like **LeetCode (aim for medium-hard problems), HackerRank, and CodeChef.**                          │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS (SQL queries, ACID          │
# │  properties, normalization), and Computer Networks.                                                             │
# │  *   **Develop & Articulate Projects:** Work on **2-3 impactful projects**, ideally using modern technologies.  │
# │  Be ready to explain your role, the challenges you faced, and your solutions in detail.                         │
# │  *   **Practice Mock Interviews & Communication:** Engage in mock technical and HR interviews to enhance your   │
# │  articulation, build confidence, and improve your ability to think on your feet.                                │
# │  *   **Stay Updated:** Keep abreast of the latest technologies and industry trends relevant to TCS's digital    │
# │  transformation initiatives.                                                                                    │
# │                                                                                                                 │
# │  TCS Digital is more than just a job; it's a launchpad for innovation and a chance to build the future. Start   │
# │  your focused preparation today, hone your skills, and showcase your potential. Your journey to becoming a      │
# │  future-ready technologist begins now!                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a career at the forefront of digital innovation? TCS Digital offers premium opportunities for B.Tech graduates to shape the future of technology. Prepare to tackle complex challenges and join an elite league of tech professionals.
#
# ### 1. The TCS Digital Hiring Process
#
# The selection journey for TCS Digital is rigorous, designed to identify top-tier talent:
#
# *   **Online Assessment (NQT Variant):** This initial hurdle is an NQT variant, featuring advanced aptitude, verbal ability, and **2-3 complex coding challenges** (often LeetCode medium-hard level). Strong problem-solving skills are key.
# *   **Technical Interview:** Expect a deep dive into **Data Structures & Algorithms (DSA)**, core Computer Science fundamentals (Operating Systems, DBMS, Computer Networks), your academic projects, and technologies listed on your resume.
# *   **Managerial/HR Interview:** This round assesses your communication skills, career aspirations, cultural fit, and behavioral traits. Be ready to discuss your projects, strengths, and how you handle challenges.
#
# ### 2. Key Technical Stack & Knowledge Areas
#
# To excel in TCS Digital, focus on these critical areas:
#
# *   **Data Structures & Algorithms (DSA):** This is non-negotiable. Develop robust problem-solving abilities.
# *   **Core Programming Languages:** Proficiency in at least one — **Java, Python, C++, or C#** — including strong Object-Oriented Programming (OOPs) concepts.
# *   **Core Computer Science Concepts:** A solid grasp of **Operating Systems, Database Management Systems (DBMS)**, and **Computer Networks** is essential.
# *   **Emerging Technologies (Conceptual):** Basic awareness of **Cloud Computing (AWS, Azure, GCP), AI/ML, Big Data, or IoT** concepts is a significant advantage.
# *   **Web Technologies/Frameworks:** Knowledge of front-end (Angular, React) or back-end (Spring Boot, Node.js) frameworks can be beneficial for specific roles.
#
# ### 3. Eligibility Criteria
#
# Ensure you meet the fundamental requirements:
#
# *   **Academic Percentage:** Generally **70% or 7 CGPA** throughout 10th, 12th, and B.Tech/B.E. (aggregate across all semesters).
# *   **Educational Gaps:** A maximum of **1-2 years** of academic gap is usually permissible, often requiring justification.
# *   **Backlogs:** **No active backlogs** are permitted at the time of application and joining.
# *   **Degree:** B.E./B.Tech in Computer Science, IT, Electronics, Electrical, Mechanical, Civil, etc., depending on the specific year's requirements.
#
# ### 4. Recent Hiring Trends
#
# Stay informed about what TCS Digital is looking for:
#
# *   **Heightened Focus on Problem-Solving:** Increased emphasis on competitive programming skills and a deep understanding of DSA.
# *   **Demand for Specialized Skillsets:** Preference for candidates with demonstrable knowledge or projects in **AI/ML, Cloud, IoT, or Cybersecurity**.
# *   **Targeting Premium Talent:** TCS Digital often seeks students from top-tier colleges or those with exceptional academic and extra-curricular achievements.
# *   **NQT as a Gateway:** The TCS National Qualifier Test (NQT) remains the primary entry point, with Digital-specific tests featuring higher difficulty levels.
#
# ### 5. Essential Preparation Tips
#
# Your roadmap to success:
#
# *   **Master DSA & Coding:** Dedicate substantial time to practicing Data Structures and Algorithms on platforms like **LeetCode (aim for medium-hard problems), HackerRank, and CodeChef.**
# *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS (SQL queries, ACID properties, normalization), and Computer Networks.
# *   **Develop & Articulate Projects:** Work on **2-3 impactful projects**, ideally using modern technologies. Be ready to explain your role, the challenges you faced, and your solutions in detail.
# *   **Practice Mock Interviews & Communication:** Engage in mock technical and HR interviews to enhance your articulation, build confidence, and improve your ability to think on your feet.
# *   **Stay Updated:** Keep abreast of the latest technologies and industry trends relevant to TCS's digital transformation initiatives.
#
# TCS Digital is more than just a job; it's a launchpad for innovation and a chance to build the future. Start your focused preparation today, hone your skills, and showcase your potential. Your journey to becoming a future-ready technologist begins now!
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 4397

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here is a placement preparation brief for TCS Digital for B.Tech students:
#
# ### Hiring Process
# *   **Online Assessment (NQT variant):** Typically includes advanced aptitude, verbal ability, and 2-3 complex coding questions (e.g., LeetCode medium-hard level).
# *   **Technical Interview:** Focuses heavily on Data Structures & Algorithms (DSA), core computer science fundamentals (OS, DBMS, CN), projects, and sometimes specific technologies mentioned in the resume.
# *   **Managerial/HR Interview:** Assesses communication skills, career aspirations, project discussions, cultural fit, and behavioral aspects.
#
# ### Technical Stack (Key areas of knowledge)
# *   **Data Structures & Algorithms (DSA):** Fundamental requirement; strong problem-solving skills are tested extensively.
# *   **Core Programming
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a career at the forefront of digital innovation? TCS Digital offers premium opportunities for B.Tech graduates to shape the future of technology. Prepare to tackle complex challenges and join an elite league of tech professionals.
#
# ### 1. The TCS Digital Hiring Process
#
# The selection journey for TCS Digital is rigorous, designed to identify top-tier talent:
#
# *   **Online Assessment (NQT Variant):** This initial hurdle is an NQT variant, featuring advanced aptitude, verbal ability, and **2-3 complex coding challenges** (often LeetCode medium-hard level). Strong problem-solving skills are key.
# *   **Technical Interview:** Expect a deep dive into **Data Structures & Algorithms (DSA)**, core Computer Science fundamentals (Operating Systems, DBM

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")
