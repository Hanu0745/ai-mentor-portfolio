# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid illustrates the progressive hierarchy of skills needed in AI, building from foundational technical skills to strategic leadership:
#
# *   **Layer 1 & 2: Data Literacy & Core AI Concepts:** The base involves understanding data (collection, cleaning, management) and fundamental AI/ML algorithms, statistics, and programming principles.
# *   **Layer 3: AI/ML Tools & Engineering:** Skills in utilizing specific AI/ML frameworks (e.g., TensorFlow, PyTorch), model development, deployment, and MLOps practices for production.
# *   **Layer 4: Domain Expertise & Problem Solving:** Applying AI effectively requires deep knowledge of the specific industry or business problem to formulate questions, interpret results, and create tangible value.
# *   **Layer 5: Strategic Vision & Ethical Leadership:** The apex focuses on AI strategy, ethical considerations, responsible AI development, understanding societal impact, and fostering human-AI collaboration.
